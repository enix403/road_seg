# %%
from pathlib import Path
import pandas as pd
from PIL import Image

import torch
import torchvision as tv
from torchvision.transforms import v2

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("data/metadata.csv")

# %%
df.head()
df['image_id'][478]
# Out:
# np.int64(17304)

# %%
ROOT_DIR = Path("data/globe-data/")

# %%
img = Image.open(ROOT_DIR / "train/17304_sat.jpg")
mask = Image.open(ROOT_DIR / "train/17304_mask.png")

# %%
preprocess = v2.Compose([
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.CenterCrop(227),
    v2.Resize((256, 256))
])

def show_pair(img, mask, p=False):
    if p:
        img = preprocess(img)
        mask = preprocess(mask)

        img = v2.functional.to_pil_image(img)
        mask = v2.functional.to_pil_image(mask)

    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(img)

    plt.subplot(1, 2, 2)
    plt.imshow(mask)

# %%
show_pair(img, mask, p=True)

# %%
show_pair(img, mask, p=False)
